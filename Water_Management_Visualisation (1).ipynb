# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
training_data = pd.read_csv("chennai_reservoir_levels.csv")

# %%
plt.plot(training_data.Date[5493:5648], training_data.POONDI[5493:5648])

# %%
plt.plot(training_data.Date[5493:5648], training_data.CHOLAVARAM[5493:5648])

# %%
plt.plot(training_data.Date[5493:5648], training_data.REDHILLS[5493:5648])

# %%
plt.plot(training_data.Date[5493:5648], training_data.CHEMBARAMBAKKAM[5493:5648])

# %%
training_data_1 = pd.read_csv("chennai_reservoir_rainfall.csv")

# %%
plt.plot(training_data_1.Date[5493:5648], training_data_1.CHEMBARAMBAKKAM[5493:5648])

# %%
plt.plot(training_data_1.Date[5455:5648], training_data_1.REDHILLS[5455:5648])

# %%
plt.plot(training_data_1.REDHILLS[5455:5648], training_data.REDHILLS[5455:5648])

# %%
plt.plot(training_data_1.REDHILLS[:300], training_data.REDHILLS[:300])

# %%
plt.plot(training_data_1.REDHILLS[:300], training_data.REDHILLS[:300])
